# %%
from IPython.display import Image

# %%
Image("img/locations.png")

# %%
Image("img/states1.png")

# %%
Image("img/states2.png")

# %%
Image("img/sources.png")

# %%
Image("img/yearly.png")

# %%
Image("img/deadliness.png")
